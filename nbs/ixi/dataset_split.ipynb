# %%
import numpy as np
import pandas as pd
import sys, os
import glob
from pprint import pprint
import csv
from collections import Counter

# %%
from pathlib import Path

# %%
df = pd.read_csv('/data-nas/sathiesh/niftynet_brain/models/ixi/dataset_split.csv', header=None)
df
#training, inference, validation
# Out:
#           0           1
# 0    IXI002   inference
# 1    IXI012    training
# 2    IXI013   inference
# 3    IXI014    training
# 4    IXI015    training
# 5    IXI016    training
# 6    IXI017    training
# 7    IXI021  validation
# 8    IXI024    training
# 9    IXI025    training
# 10   IXI027    training
# 11   IXI028   inference
# 12   IXI029    training
# 13   IXI030    training
# 14   IXI031    training
# 15   IXI033    training
# 16   IXI034    training
# 17   IXI036    training
# 18   IXI037    training
# 19   IXI038    training
# 20   IXI039  validation
# 21   IXI040    training
# 22   IXI041    training
# 23   IXI042    training
# 24   IXI043    training
# 25   IXI044   inference
# 26   IXI045    training
# 27   IXI046    training
# 28   IXI048    training
# 29   IXI049    training
# ..      ...         ...
# 404  IXI606    training
# 405  IXI608    training
# 406  IXI609    training
# 407  IXI610    training
# 408  IXI611    training
# 409  IXI612    training
# 410  IXI613    training
# 411  IXI614    training
# 412  IXI619  validation
# 413  IXI621    training
# 414  IXI622  validation
# 415  IXI623    training
# 416  IXI625    training
# 417  IXI626    training
# 418  IXI627    training
# 419  IXI630   inference
# 420  IXI631  validation
# 421  IXI632    training
# 422  IXI633  validation
# 423  IXI634    training
# 424  IXI635    training
# 425  IXI636    training
# 426  IXI637    training
# 427  IXI638   inference
# 428  IXI639    training
# 429  IXI641    training
# 430  IXI643    training
# 431  IXI646    training
# 432  IXI651    training
# 433  IXI661    training
#
# [434 rows x 2 columns]

# %%
len(df)
# Out:
# 500

# %%
df[1] = 'training' #values are now training 
df.head()
# Out:
#         0         1
# 0  IXI002  training
# 1  IXI012  training
# 2  IXI013  training
# 3  IXI014  training
# 4  IXI015  training

# %%
df.to_csv('/data-nas/sathiesh/niftynet_brain/models/ixi/dataset_split.csv', index=False,header=None)
